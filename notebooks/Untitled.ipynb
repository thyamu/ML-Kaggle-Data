# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import time 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
os.getcwd()
# Out:
# '/Users/hkim78/work/MLKaggle/notebooks'

# %%
dir_data = "../data"
path_data = os.path.join(dir_data, "diabetes_data.csv")
df = pd.read_csv(path_data)

# %% [markdown]
# #### Basic check

# %%
df.describe()
# Out:
#                 Age           Sex      HighChol     CholCheck           BMI  \
# count  70692.000000  70692.000000  70692.000000  70692.000000  70692.000000
# mean       8.584055      0.456997      0.525703      0.975259     29.856985
# std        2.852153      0.498151      0.499342      0.155336      7.113954
# min        1.000000      0.000000      0.000000      0.000000     12.000000
# 25%        7.000000      0.000000      0.000000      1.000000     25.000000
# 50%        9.000000      0.000000      1.000000      1.000000     29.000000
# 75%       11.000000      1.000000      1.000000      1.000000     33.000000
# max       13.000000      1.000000      1.000000      1.000000     98.000000
#
#              Smoker  HeartDiseaseorAttack  PhysActivity        Fruits  \
# count  70692.000000          70692.000000  70692.000000  70692.000000
# mean       0.475273              0.147810      0.703036      0.611795
# std        0.499392              0.354914      0.456924      0.487345
# ...

# %%
df.isna().sum()
# Out:
# Age                     0
# Sex                     0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Stroke                  0
# HighBP                  0
# Diabetes                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70692 entries, 0 to 70691
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   70692 non-null  float64
#  1   Sex                   70692 non-null  float64
#  2   HighChol              70692 non-null  float64
#  3   CholCheck             70692 non-null  float64
#  4   BMI                   70692 non-null  float64
#  5   Smoker                70692 non-null  float64
#  6   HeartDiseaseorAttack  70692 non-null  float64
#  7   PhysActivity          70692 non-null  float64
#  8   Fruits                70692 non-null  float64
#  9   Veggies               70692 non-null  float64
#  10  HvyAlcoholConsump     70692 non-null  float64
#  11  GenHlth               70692 non-null  float64
#  12  MentHlth              70692 non-null  float64
#  13  PhysHlth              70692 non-null  float64
# ...

# %% [markdown]
# #### Setting Seaborn Style

# %%
sns.set(rc={'figure.facecolor':'white'})
sns.set_theme(style="ticks")

# %% [markdown]
# #### density plot

# %%
features = list(df.columns)

for x in features:
    sns.displot(data=df, x=x, kind="kde")

# %%
def subplots_by_rows_cols(data, nbr_rows, nbr_cols):

    feat = list(data.columns)

    fig, axs = plt.subplots(nbr_rows, nbr_cols, figsize=(5 * nbr_rows, 3 * nbr_cols))
    
    i =0
    for col_index in range(nbr_cols):#for domain in rows:
        for row_index in range(nbr_rows): #for col in range(1, len(columns) + 1):
            axs[row_index, col_index].set_title('%s'%(feat[i]))
            axs[row_index, col_index].tick_params(labelsize=12)       
            axs[row_index, col_index].hist(data[feat[i]], orientation='horizontal', histtype='step')
            i += 1
            
    for ax in axs.flat:
        ax.set(xlabel='x-label', ylabel='y-label')
    
    # for ax in axs.flat:
    #     ax.label_outer()
    
    plt.tight_layout()

# %%
subplots_by_rows_cols(df, 5, 4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-d42b23d7b4c5> in <module>
# ----> 1 subplots_by_rows_cols(df, 5, 4)
#
# <ipython-input-24-7f2f086d57f8> in subplots_by_rows_cols(data, nbr_rows, nbr_cols)
#       8     for col_index in range(nbr_cols):#for domain in rows:
#       9         for row_index in range(nbr_rows): #for col in range(1, len(columns) + 1):
# ---> 10             axs[row_index, col_index].set_title('%s'%(feat[i]))
#      11             axs[row_index, col_index].tick_params(labelsize=12)
#      12             axs[row_index, col_index].hist(data[feat[i]], orientation='horizontal', histtype='step')
#
# IndexError: list index out of range

# %%
st = time.time()
sns.pairplot(df, plot_kws={"s": 4}) 
et = time.time()
print("time:", et-st)

#time for df2d: ~51s
# Out:
# time: 27.394207000732422
